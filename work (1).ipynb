# %% [markdown]
# # Assignment nº1
# ## Lung Cancer Classification using Computerized Tomography (CT) Data

# %% [markdown]
# ##### Work assembled by Alejandro Gonçalves, Francisca Mihalache, João Sousa and Vitor Ferreira.

# %% [markdown]
# ## Table of contents <a name="contents"></a>
#
# 1. [Introduction](#introduction)
# 2. [Data](#data)
#
#    - 2.1 [Data cleaning](#cleaning)

# %% [markdown]
# ## Introduction <a name="introduction"></a>
# [[go back to the top]](#contents)
#
# Lung cancer is the leading cause of cancer-related deaths, with survival rates heavily dependent on early detection. While CT imaging is a valuable non-invasive tool for detecting lung nodules, only 16% of cases are diagnosed early.
#
# Computer-Aided Diagnosis (CAD) systems can help assess malignancy risk, but variability in human interpretation and large data volumes pose challenges. Radiomics, by extracting quantitative data from medical images, offers the potential for non-invasive diagnostic tools.
#
# Previous studies using technologies like CNNs (convolutional neural networks), PyRadiomics, and machine learning algorithms have shown promise, but ethical and legal challenges persist. This project aims to develop an advanced lung nodule malignancy prediction system using radiomics and deep learning to improve early diagnosis and reduce variability.

# %% [markdown]
# As suggested by the professor's guidelines, we will implement the CRISP-DM (Cross Industry Standard Process for Data Mining) methodology for this project. This well-established framework consists of six phases: Business Understanding, Data Understanding, Data Preparation, Modeling, Evaluation, and Deployment, however, since deployment is not relevant to the scope of this academic project, we will focus on the first five phases.

# %% [markdown]
# ### Imports
# [[go back to the top]](#contents)
#
# Here are the imports we need.

# %%
import numpy as np 
import pandas as pd 

import matplotlib.pyplot as plt
import pydicom

import radiomics
from radiomics import featureextractor, getFeatureClasses
import pylidc as pl

# %% [markdown]
# ###  Data <a name="data"></a>
# [[go back to the top]](#contents)
#
# The data was obtained from the LIDC-IDRI collection, a database of thoracic computed tomography (CT) images from a total of 1010 patients, accompanied by expert radiologist annotations. This dataset is available in this link https://www.cancerimagingarchive.net/collection/lidc-idri/.

# %% [markdown]
# ### Data cleaning <a name="cleaning"></a>
# [[go back to the topic]](#data)
#
# In this section we will clean up the data.

# %%
df= pd.read_csv("LIDC-IDRI_MetaData.csv")
df_sorted= df.sort_values(by='Subject ID')
df_sorted
# Out:
#           Subject ID                                          Study UID  \
# 348   LIDC-IDRI-0001  1.3.6.1.4.1.14519.5.2.1.6279.6001.298806137288...
# 186   LIDC-IDRI-0001  1.3.6.1.4.1.14519.5.2.1.6279.6001.175012972118...
# 1100  LIDC-IDRI-0002  1.3.6.1.4.1.14519.5.2.1.6279.6001.116951808801...
# 1141  LIDC-IDRI-0002  1.3.6.1.4.1.14519.5.2.1.6279.6001.490157381160...
# 189   LIDC-IDRI-0003  1.3.6.1.4.1.14519.5.2.1.6279.6001.202063331127...
# ...              ...                                                ...
# 990   LIDC-IDRI-1008  1.3.6.1.4.1.14519.5.2.1.6279.6001.339975625902...
# 1248  LIDC-IDRI-1009  1.3.6.1.4.1.14519.5.2.1.6279.6001.849069697860...
# 1120  LIDC-IDRI-1010  1.3.6.1.4.1.14519.5.2.1.6279.6001.145373944605...
# 749   LIDC-IDRI-1011  1.3.6.1.4.1.14519.5.2.1.6279.6001.287560874054...
# 242   LIDC-IDRI-1012  1.3.6.1.4.1.14519.5.2.1.6279.6001.676549258486...
#
#            Study Description             Study Date  \
# 348                      NaN  2000-01-01 00:00:00.0
# 186                      NaN  2000-01-01 00:00:00.0
# 1100                     NaN  2000-01-01 00:00:00.0
# 1141                     NaN  2000-01-01 00:00:00.0
# 189                      NaN  2000-01-01 00:00:00.0
# ...                      ...                    ...
# 990                      NaN  2000-01-01 00:00:00.0
# 1248    CT THORAX W/CONTRAST  2000-01-01 00:00:00.0
# 1120  CT ANGIO CHEST (NON-CO  2000-01-01 00:00:00.0
# 749     CT THORAX W/CONTRAST  2000-01-01 00:00:00.0
# 242                    CHEST  2000-01-01 00:00:00.0
#
#                                               Series ID Series Description  \
# 348   1.3.6.1.4.1.14519.5.2.1.6279.6001.179049373636...                NaN
# 186   1.3.6.1.4.1.14519.5.2.1.6279.6001.141365756818...                NaN
# 1100  1.3.6.1.4.1.14519.5.2.1.6279.6001.493562949900...                NaN
# 1141  1.3.6.1.4.1.14519.5.2.1.6279.6001.619372068417...                NaN
# 189   1.3.6.1.4.1.14519.5.2.1.6279.6001.142026812390...                NaN
# ...                                                 ...                ...
# 990   1.3.6.1.4.1.14519.5.2.1.6279.6001.332510758903...                NaN
# 1248  1.3.6.1.4.1.14519.5.2.1.6279.6001.855232435861...     Recon 2: CHEST
# 1120  1.3.6.1.4.1.14519.5.2.1.6279.6001.550599855064...      BOTTOM TO TOP
# 749   1.3.6.1.4.1.14519.5.2.1.6279.6001.272123398257...              CHEST
# 242   1.3.6.1.4.1.14519.5.2.1.6279.6001.153646219551...                NaN
#
#       Number of images  File Size (Bytes) Collection Name Modality  \
# 348                133           70018838       LIDC-IDRI       CT
# 186                  2           16357620       LIDC-IDRI       DX
# 1100                 1            6909958       LIDC-IDRI       DX
# 1141               261          137396696       LIDC-IDRI       CT
# 189                  5           38580794       LIDC-IDRI       DX
# ...                ...                ...             ...      ...
# 990                115           60517648       LIDC-IDRI       CT
# 1248               125           65830674       LIDC-IDRI       CT
# 1120               252          132720966       LIDC-IDRI       CT
# 749                133           70030058       LIDC-IDRI       CT
# 242                166           87399298       LIDC-IDRI       CT
#
#             Manufacturer
# 348   GE MEDICAL SYSTEMS
# 186   GE MEDICAL SYSTEMS
# 1100  GE MEDICAL SYSTEMS
# 1141  GE MEDICAL SYSTEMS
# 189   GE MEDICAL SYSTEMS
# ...                  ...
# 990              TOSHIBA
# 1248  GE MEDICAL SYSTEMS
# 1120  GE MEDICAL SYSTEMS
# 749   GE MEDICAL SYSTEMS
# 242   GE MEDICAL SYSTEMS
#
# [1308 rows x 11 columns]

# %%
df1= pd.read_excel('tcia-diagnosis-data-2012-04-20.xls')
df1_sorted= df1.sort_values(by= 'TCIA Patient ID')
df1_sorted

#pip install xlrd (tem de rodar isto para poder mexer com o excel)
# Out:
#     TCIA Patient ID  \
# 0    LIDC-IDRI-0068
# 1    LIDC-IDRI-0071
# 2    LIDC-IDRI-0072
# 3    LIDC-IDRI-0088
# 4    LIDC-IDRI-0090
# ..              ...
# 152  LIDC-IDRI-0994
# 153  LIDC-IDRI-1002
# 154  LIDC-IDRI-1004
# 155  LIDC-IDRI-1010
# 156  LIDC-IDRI-1011
#
#      Diagnosis at the Patient Level\n0=Unknown\n1=benign or non-malignant disease\n2= malignant, primary lung cancer\n3 = malignant metastatic\n  \
# 0                                                    3
# 1                                                    3
# 2                                                    2
# 3                                                    3
# 4                                                    2
# ..                                                 ...
# 152                                                  2
# 153                                                  2
# 154                                                  2
# 155                                                  0
# 156                                                  3
#
#      Diagnosis Method\n0 = unknown\n1 = review of radiological images to show 2 years of stable nodule\n2 = biopsy\n3 = surgical resection\n4 = progression or response  \
# 0                                                    4
# 1                                                    1
# 2                                                    4
# 3                                                    0
# 4                                                    3
# ..                                                 ...
# 152                                                  3
# 153                                                  2
# 154                                                  3
# 155                                                  0
# 156                                                  2
#
#     Primary tumor site for metastatic disease  \
# 0                          Head & Neck Cancer
# 1                                Head & Neck
# 2                                 Lung Cancer
# 3                              Uterine Cancer
# 4                                       NSCLC
# ..                                        ...
# 152                         LUL Large cell CA
# 153                  non-small cell carcinoma
# 154                                 LUL NSCLC
# 155                                  lymphoma
# 156        small-cell carcinoma of the tongue
#
#      Nodule 1\nDiagnosis at the Nodule Level \n0=Unknown\n1=benign or non-malignant disease\n2= malignant, primary lung cancer\n3 = malignant metastatic)\n  \
# 0                                                  3.0
# 1                                                  1.0
# 2                                                  1.0
# 3                                                  0.0
# 4                                                  2.0
# ..                                                 ...
# 152                                                2.0
# 153                                                NaN
# 154                                                2.0
# 155                                                0.0
# 156                                                3.0
#
#      Nodule 1\nDiagnosis Method at the Nodule Level\n0 = unknown\n1 = review of radiological images to show 2 years of stable nodule\n2 = biopsy\n3 = surgical resection\n4 = progression or response\n  \
# 0                                                  4.0
# 1                                                  1.0
# 2                                                  4.0
# 3                                                  0.0
# 4                                                  3.0
# ..                                                 ...
# 152                                                3.0
# 153                                                NaN
# 154                                                3.0
# 155                                                0.0
# 156                                                2.0
#
#      Nodule 2\nDiagnosis at the Nodule Level \n0=Unknown\n1=benign or non-malignant disease\n2= malignant, primary lung cancer\n3 = malignant metastatic)\n  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 152                                                NaN
# 153                                                NaN
# 154                                                NaN
# 155                                                NaN
# 156                                                3.0
#
#      Nodule 2\nDiagnosis Method at the Nodule Level\n0 = unknown\n1 = review of radiological images to show 2 years of stable nodule\n2 = biopsy\n3 = surgical resection\n4 = progression or response\n  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 152                                                NaN
# 153                                                NaN
# 154                                                NaN
# 155                                                NaN
# 156                                                4.0
#
#     Nodule 3\nDiagnosis at the Nodule Level \n0=Unknown\n1=benign or non-malignant disease\n2= malignant, primary lung cancer\n3 = malignant metastatic)\n  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 152                                                NaN
# 153                                                NaN
# 154                                                NaN
# 155                                                NaN
# 156                                                NaN
#
#     Nodule 3\nDiagnosis Method at the Nodule Level\n0 = unknown\n1 = review of radiological images to show 2 years of stable nodule\n2 = biopsy\n3 = surgical resection\n4 = progression or response\n  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 152                                                NaN
# 153                                                NaN
# 154                                                NaN
# 155                                                NaN
# 156                                                NaN
#
#      Nodule 4\nDiagnosis at the Nodule Level \n0=Unknown\n1=benign or non-malignant disease\n2= malignant, primary lung cancer\n3 = malignant metastatic)\n  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 152                                                NaN
# 153                                                NaN
# 154                                                NaN
# 155                                                NaN
# 156                                                NaN
#
#      Nodule 4\nDiagnosis Method at the Nodule Level\n0 = unknown\n1 = review of radiological images to show 2 years of stable nodule\n2 = biopsy\n3 = surgical resection\n4 = progression or response\n  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 152                                                NaN
# 153                                                NaN
# 154                                                NaN
# 155                                                NaN
# 156                                                NaN
#
#      Nodule 5\nDiagnosis at the Nodule Level \n0=Unknown\n1=benign or non-malignant disease\n2= malignant, primary lung cancer\n3 = malignant metastatic)\n  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 152                                                NaN
# 153                                                NaN
# 154                                                NaN
# 155                                                NaN
# 156                                                NaN
#
#      Nodule 5\nDiagnosis Method at the Nodule Level\n0 = unknown\n1 = review of radiological images to show 2 years of stable nodule\n2 = biopsy\n3 = surgical resection\n4 = progression or response\n
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 152                                                NaN
# 153                                                NaN
# 154                                                NaN
# 155                                                NaN
# 156                                                NaN
#
# [157 rows x 14 columns]

# %%
df2= pd.read_excel('lidc-idri-nodule-counts-6-23-2015.xlsx')
df2_sorted= df2.sort_values(by= 'TCIA Patent ID')
df2_sorted
#pip install openpyxl
# Out:
#       TCIA Patent ID  Total Number of Nodules*   Number of Nodules >=3mm**  \
# 0     LIDC-IDRI-0001                          4                          1
# 1     LIDC-IDRI-0002                         12                          1
# 2     LIDC-IDRI-0003                          4                          4
# 3     LIDC-IDRI-0004                          4                          1
# 4     LIDC-IDRI-0005                          9                          3
# ...              ...                        ...                        ...
# 1014  LIDC-IDRI-1009                          2                          1
# 1015  LIDC-IDRI-1010                         10                          1
# 1016  LIDC-IDRI-1011                          4                          4
# 1017  LIDC-IDRI-1012                          1                          1
# 1018             NaN                       7371                       2669
#
#       Number of Nodules <3mm***  Unnamed: 4  \
# 0                             3         NaN
# 1                            11         NaN
# 2                             0         NaN
# 3                             3         NaN
# 4                             6         NaN
# ...                         ...         ...
# 1014                          1         NaN
# 1015                          9         NaN
# 1016                          0         NaN
# 1017                          0         NaN
# 1018                       4702         NaN
#
#                                              Unnamed: 5
# 0                                                   NaN
# 1     *total number of lesions that received either ...
# 2     **total number of lesions that received a "nod...
# 3     ***total number of lesions that received a "no...
# 4                                                   NaN
# ...                                                 ...
# 1014                                                NaN
# 1015                                                NaN
# 1016                                                NaN
# 1017                                                NaN
# 1018                                                NaN
#
# [1019 rows x 6 columns]

# %% [markdown]
# ## pylidc

# %%
scans = pl.query(pl.Scan).all()
print(scans[0])
print(len(scans))
# Out:
# Scan(id=1,patient_id=LIDC-IDRI-0078)
# 1018

# %%
print(scans[0].patient_id,
      scans[0].pixel_spacing,
      scans[0].slice_thickness,
      scans[0].slice_spacing)
# Out:
# LIDC-IDRI-0078 0.65 3.0 3.0

# %%
print(len(scans[0].annotations))
# Out:
# 13

# %%
annotations = pl.query(pl.Annotation).all() # as anotacoes fazem parte da biblioteca pylidc
# Exibir todas as anotações
#for ann in annotations:
    #print(ann)

# %%
scans[0].annotations
# Out:
# [Annotation(id=1,scan_id=1),
#  Annotation(id=2,scan_id=1),
#  Annotation(id=3,scan_id=1),
#  Annotation(id=4,scan_id=1),
#  Annotation(id=5,scan_id=1),
#  Annotation(id=6,scan_id=1),
#  Annotation(id=7,scan_id=1),
#  Annotation(id=8,scan_id=1),
#  Annotation(id=9,scan_id=1),
#  Annotation(id=10,scan_id=1),
#  Annotation(id=11,scan_id=1),
#  Annotation(id=12,scan_id=1),
#  Annotation(id=13,scan_id=1)]

# %%
nods = scans[0].cluster_annotations()
print("%s has %d nodules." % (scans[0], len(nods)))

for i,nod in enumerate(nods):
    print("Nodule %d has %d annotations." % (i+1, len(nods[i])))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[69], line 1
# ----> 1 nods = scans[0].cluster_annotations()
#       2 print("%s has %d nodules." % (scans[0], len(nods)))
#       4 for i,nod in enumerate(nods):
#
# File ~/opt/anaconda3/envs/projj/lib/python3.9/site-packages/pylidc/Scan.py:439, in Scan.cluster_annotations(self, metric, tol, factor, min_tol, return_distance_matrix, verbose)
#     437 for i in range(N):
#     438     for j in range(i+1,N):
# --> 439         D[i,j] = D[j,i] = metric(self.annotations[i],
#     440                                  self.annotations[j])
#     442 adjacency = D <= tol
#     443 nnods, cids = connected_components(adjacency, directed=False)
#
# File ~/opt/anaconda3/envs/projj/lib/python3.9/site-packages/pylidc/annotation_distance_metrics.py:27, in <lambda>(a, b)
#      24     else:
#      25         raise ValueError('invalid `which` value.')
# ---> 27 metrics['min'] = lambda a,b: pairdist(a,b,'min')
#      28 metrics['max'] = lambda a,b: pairdist(a,b,'max')
#      29 metrics['avg'] = lambda a,b: pairdist(a,b,'avg')
#
# File ~/opt/anaconda3/envs/projj/lib/python3.9/site-packages/pylidc/annotation_distance_metrics.py:15, in pairdist(ann1, ann2, which)
#       6 def pairdist(ann1, ann2, which):
#       7     """
#       8     Compute the pairwise euclidean distance between
#       9     the contour boundary points, and return the
#    (...)
#      13         One of 'min', 'max', or 'avg'.
#      14     """
# ---> 15     dists = cdist(ann1.contours_matrix,
#      16                   ann2.contours_matrix)
#      18     if   which == 'min':
#      19         return dists.min()
#
# File ~/opt/anaconda3/envs/projj/lib/python3.9/site-packages/pylidc/Annotation.py:968, in Annotation.contours_matrix(self)
#     963 @property
#     964 def contours_matrix(self):
#     965     """
#     966     All the contour index values a 3D numpy array.
#     967     """
# --> 968     return np.vstack([c.to_matrix(include_k=True)
#     969                             for c in sorted(self.contours,
#     970                                     key=lambda c: c.image_z_position)])
#
# File ~/opt/anaconda3/envs/projj/lib/python3.9/site-packages/pylidc/Annotation.py:968, in <listcomp>(.0)
#     963 @property
#     964 def contours_matrix(self):
#     965     """
#     966     All the contour index values a 3D numpy array.
#     967     """
# --> 968     return np.vstack([c.to_matrix(include_k=True)
#     969                             for c in sorted(self.contours,
#     970                                     key=lambda c: c.image_z_position)])
#
# File ~/opt/anaconda3/envs/projj/lib/python3.9/site-packages/pylidc/Contour.py:111, in Contour.to_matrix(self, include_k)
#     109 k  = np.ones(ij.shape[0])*self.image_k_position
#     110 zs = self.annotation.contour_slice_zvals
# --> 111 return np.c_[ij, k].astype(np.int)
#
# File ~/opt/anaconda3/envs/projj/lib/python3.9/site-packages/numpy/__init__.py:324, in __getattr__(attr)
#     319     warnings.warn(
#     320         f"In the future `np.{attr}` will be defined as the "
#     321         "corresponding NumPy scalar.", FutureWarning, stacklevel=2)
#     323 if attr in __former_attrs__:
# --> 324     raise AttributeError(__former_attrs__[attr])
#     326 if attr == 'testing':
#     327     import numpy.testing as testing
#
# AttributeError: module 'numpy' has no attribute 'int'.
# `np.int` was a deprecated alias for the builtin `int`. To avoid this error in existing code, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
